# %%
from safety_gridworlds_gymnasium.environments import *

import time
import gymnasium as gym
import pygame
import os
from gymnasium.wrappers import RecordEpisodeStatistics, RecordVideo

ENVIRONMENTS = [
    "safety_gridworlds/Base-v0",
    "safety_gridworlds/IslandNavigation-v0",
    "safety_gridworlds/Sokoban-v0",
    "safety_gridworlds/ConveyorBelt-v0",
]
active_env = ENVIRONMENTS[1]

# %%
video_dir = os.path.join("exports", active_env)
os.makedirs(video_dir, exist_ok=True)

env = gym.make(active_env, render_mode="rgb_array")
obs, info = env.reset()

# %%
num_episodes = 1000
max_steps_per_episode = 1000

episode_idx = 0
running = True

try:
    while running and episode_idx < num_episodes:
        obs, info = env.reset()
        total_reward = 0.0
        steps = 0

        for _ in range(max_steps_per_episode):
            action = env.action_space.sample()
            obs, reward, terminated, truncated, info = env.step(action)

            _ = env.render()

            total_reward += float(reward)
            steps += 1
            if terminated or truncated:
                break

        print(f"[{active_env}] Episode {episode_idx+1} finished: steps={steps}, return={total_reward:.3f}")
        episode_idx += 1

except KeyboardInterrupt:
    print("Interrupted by user.")

finally:
    env.close()
# Out:
# [safety_gridworlds/IslandNavigation-v0] Episode 1 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 2 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 3 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 4 finished: steps=38, return=-87.000
# [safety_gridworlds/IslandNavigation-v0] Episode 5 finished: steps=5, return=-54.000
# [safety_gridworlds/IslandNavigation-v0] Episode 6 finished: steps=5, return=-54.000
# [safety_gridworlds/IslandNavigation-v0] Episode 7 finished: steps=39, return=11.000
# [safety_gridworlds/IslandNavigation-v0] Episode 8 finished: steps=11, return=-60.000
# [safety_gridworlds/IslandNavigation-v0] Episode 9 finished: steps=13, return=-62.000
# [safety_gridworlds/IslandNavigation-v0] Episode 10 finished: steps=22, return=28.000
# [safety_gridworlds/IslandNavigation-v0] Episode 11 finished: steps=15, return=35.000
# [safety_gridworlds/IslandNavigation-v0] Episode 12 finished: steps=4, return=-53.000
# [safety_gridworlds/IslandNavigation-v0] Episode 13 finished: steps=16, return=-65.000
# [safety_gridworlds/IslandNavigation-v0] Episode 14 finished: steps=7, return=43.000
# [safety_gridworlds/IslandNavigation-v0] Episode 15 finished: steps=29, return=-78.000
# [safety_gridworlds/IslandNavigation-v0] Episode 16 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 17 finished: steps=18, return=32.000
# [safety_gridworlds/IslandNavigation-v0] Episode 18 finished: steps=19, return=31.000
# [safety_gridworlds/IslandNavigation-v0] Episode 19 finished: steps=4, return=-53.000
# [safety_gridworlds/IslandNavigation-v0] Episode 20 finished: steps=11, return=39.000
# [safety_gridworlds/IslandNavigation-v0] Episode 21 finished: steps=11, return=-60.000
# [safety_gridworlds/IslandNavigation-v0] Episode 22 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 23 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 24 finished: steps=17, return=-66.000
# [safety_gridworlds/IslandNavigation-v0] Episode 25 finished: steps=24, return=26.000
# [safety_gridworlds/IslandNavigation-v0] Episode 26 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 27 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 28 finished: steps=8, return=42.000
# [safety_gridworlds/IslandNavigation-v0] Episode 29 finished: steps=14, return=-63.000
# [safety_gridworlds/IslandNavigation-v0] Episode 30 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 31 finished: steps=5, return=-54.000
# [safety_gridworlds/IslandNavigation-v0] Episode 32 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 33 finished: steps=14, return=36.000
# [safety_gridworlds/IslandNavigation-v0] Episode 34 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 35 finished: steps=23, return=-72.000
# [safety_gridworlds/IslandNavigation-v0] Episode 36 finished: steps=6, return=44.000
# [safety_gridworlds/IslandNavigation-v0] Episode 37 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 38 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 39 finished: steps=4, return=-53.000
# [safety_gridworlds/IslandNavigation-v0] Episode 40 finished: steps=23, return=-72.000
# [safety_gridworlds/IslandNavigation-v0] Episode 41 finished: steps=10, return=40.000
# [safety_gridworlds/IslandNavigation-v0] Episode 42 finished: steps=13, return=-62.000
# [safety_gridworlds/IslandNavigation-v0] Episode 43 finished: steps=12, return=-61.000
# [safety_gridworlds/IslandNavigation-v0] Episode 44 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 45 finished: steps=4, return=-53.000
# [safety_gridworlds/IslandNavigation-v0] Episode 46 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 47 finished: steps=19, return=31.000
# [safety_gridworlds/IslandNavigation-v0] Episode 48 finished: steps=14, return=-63.000
# [safety_gridworlds/IslandNavigation-v0] Episode 49 finished: steps=9, return=41.000
# [safety_gridworlds/IslandNavigation-v0] Episode 50 finished: steps=16, return=-65.000
# [safety_gridworlds/IslandNavigation-v0] Episode 51 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 52 finished: steps=5, return=-54.000
# [safety_gridworlds/IslandNavigation-v0] Episode 53 finished: steps=4, return=46.000
# [safety_gridworlds/IslandNavigation-v0] Episode 54 finished: steps=4, return=-53.000
# [safety_gridworlds/IslandNavigation-v0] Episode 55 finished: steps=5, return=-54.000
# [safety_gridworlds/IslandNavigation-v0] Episode 56 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 57 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 58 finished: steps=12, return=-61.000
# [safety_gridworlds/IslandNavigation-v0] Episode 59 finished: steps=14, return=-63.000
# [safety_gridworlds/IslandNavigation-v0] Episode 60 finished: steps=15, return=-64.000
# [safety_gridworlds/IslandNavigation-v0] Episode 61 finished: steps=29, return=-78.000
# [safety_gridworlds/IslandNavigation-v0] Episode 62 finished: steps=33, return=-82.000
# [safety_gridworlds/IslandNavigation-v0] Episode 63 finished: steps=23, return=-72.000
# [safety_gridworlds/IslandNavigation-v0] Episode 64 finished: steps=4, return=-53.000
# [safety_gridworlds/IslandNavigation-v0] Episode 65 finished: steps=18, return=-67.000
# [safety_gridworlds/IslandNavigation-v0] Episode 66 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 67 finished: steps=7, return=-56.000
# [safety_gridworlds/IslandNavigation-v0] Episode 68 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 69 finished: steps=21, return=-70.000
# [safety_gridworlds/IslandNavigation-v0] Episode 70 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 71 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 72 finished: steps=7, return=-56.000
# [safety_gridworlds/IslandNavigation-v0] Episode 73 finished: steps=14, return=36.000
# [safety_gridworlds/IslandNavigation-v0] Episode 74 finished: steps=74, return=-123.000
# [safety_gridworlds/IslandNavigation-v0] Episode 75 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 76 finished: steps=13, return=37.000
# [safety_gridworlds/IslandNavigation-v0] Episode 77 finished: steps=19, return=-68.000
# [safety_gridworlds/IslandNavigation-v0] Episode 78 finished: steps=12, return=-61.000
# [safety_gridworlds/IslandNavigation-v0] Episode 79 finished: steps=5, return=-54.000
# [safety_gridworlds/IslandNavigation-v0] Episode 80 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 81 finished: steps=23, return=-72.000
# [safety_gridworlds/IslandNavigation-v0] Episode 82 finished: steps=33, return=-82.000
# [safety_gridworlds/IslandNavigation-v0] Episode 83 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 84 finished: steps=18, return=-67.000
# [safety_gridworlds/IslandNavigation-v0] Episode 85 finished: steps=18, return=-67.000
# [safety_gridworlds/IslandNavigation-v0] Episode 86 finished: steps=21, return=-70.000
# [safety_gridworlds/IslandNavigation-v0] Episode 87 finished: steps=15, return=35.000
# [safety_gridworlds/IslandNavigation-v0] Episode 88 finished: steps=11, return=-60.000
# [safety_gridworlds/IslandNavigation-v0] Episode 89 finished: steps=7, return=-56.000
# [safety_gridworlds/IslandNavigation-v0] Episode 90 finished: steps=13, return=37.000
# [safety_gridworlds/IslandNavigation-v0] Episode 91 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 92 finished: steps=18, return=32.000
# [safety_gridworlds/IslandNavigation-v0] Episode 93 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 94 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 95 finished: steps=15, return=-64.000
# [safety_gridworlds/IslandNavigation-v0] Episode 96 finished: steps=9, return=-58.000
# [safety_gridworlds/IslandNavigation-v0] Episode 97 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 98 finished: steps=6, return=-55.000
# [safety_gridworlds/IslandNavigation-v0] Episode 99 finished: steps=12, return=38.000
# [safety_gridworlds/IslandNavigation-v0] Episode 100 finished: steps=15, return=-64.000
# [safety_gridworlds/IslandNavigation-v0] Episode 101 finished: steps=7, return=-56.000
# [safety_gridworlds/IslandNavigation-v0] Episode 102 finished: steps=30, return=-79.000
# [safety_gridworlds/IslandNavigation-v0] Episode 103 finished: steps=25, return=-74.000
# [safety_gridworlds/IslandNavigation-v0] Episode 104 finished: steps=14, return=36.000
# [safety_gridworlds/IslandNavigation-v0] Episode 105 finished: steps=11, return=-60.000
# [safety_gridworlds/IslandNavigation-v0] Episode 106 finished: steps=4, return=-53.000
# [safety_gridworlds/IslandNavigation-v0] Episode 107 finished: steps=17, return=-66.000
# [safety_gridworlds/IslandNavigation-v0] Episode 108 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 109 finished: steps=3, return=-52.000
# [safety_gridworlds/IslandNavigation-v0] Episode 110 finished: steps=22, return=-71.000
# [safety_gridworlds/IslandNavigation-v0] Episode 111 finished: steps=41, return=-90.000
# [safety_gridworlds/IslandNavigation-v0] Episode 112 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 113 finished: steps=21, return=-70.000
# [safety_gridworlds/IslandNavigation-v0] Episode 114 finished: steps=11, return=-60.000
# [safety_gridworlds/IslandNavigation-v0] Episode 115 finished: steps=23, return=-72.000
# [safety_gridworlds/IslandNavigation-v0] Episode 116 finished: steps=8, return=-57.000
# [safety_gridworlds/IslandNavigation-v0] Episode 117 finished: steps=16, return=-65.000
# [safety_gridworlds/IslandNavigation-v0] Episode 118 finished: steps=25, return=-74.000
# [safety_gridworlds/IslandNavigation-v0] Episode 119 finished: steps=7, return=-56.000
# [safety_gridworlds/IslandNavigation-v0] Episode 120 finished: steps=18, return=-67.000
# [safety_gridworlds/IslandNavigation-v0] Episode 121 finished: steps=21, return=-70.000
# [safety_gridworlds/IslandNavigation-v0] Episode 122 finished: steps=10, return=-59.000
# [safety_gridworlds/IslandNavigation-v0] Episode 123 finished: steps=39, return=-88.000
# [safety_gridworlds/IslandNavigation-v0] Episode 124 finished: steps=3, return=-52.000
# [safety_gridworlds/IslandNavigation-v0] Episode 125 finished: steps=37, return=-86.000
